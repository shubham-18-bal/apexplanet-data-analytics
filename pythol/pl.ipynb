# %% [markdown]
# # PYTHON
# ## Python is a high level interpreted language, in business analytics it is  used to --
# ### collect data
# ### analyze data
# ### clean data
# ### transform data
# ### find patterns
# ### create vizualizations
# ### build predective models

# %%
print("bholu")
# Out:
# bholu

# %%
shubham = "baliraj"
print(shubham)
# Out:
# baliraj

# %%
name = input("name please :")
print("your name is :", name)
# Out:
# your name is : aman

# %% [markdown]
# ## VARIABLE
# ### It is a name used to store value

# %%
name = input("type your name")
print ("your name is Rowdy" , name)
# Out:
# your name is Rowdy BHOLU

# %% [markdown]
# ## DATATYPES
# ### A datatypes is something that tells python what type of data it is , e.g - int, float, charachter

# %%
# int
a = 12.4
b = 5j
print (a+b)
print (type(a))
print (type(b))
# Out:
# (12.4+5j)
# <class 'float'>
# <class 'complex'>

# %%
print(5<6)
# Out:
# True

# %%
# string
a = "Hammer"
print(a)
print(a[2])         #indexing
print(a[1:4])       #slicing
print(a.lower())  

print(a.replace ("Hammer" , "Nails"))
# Out:
# Hammer
# m
# amm
# hammer
# Nails
